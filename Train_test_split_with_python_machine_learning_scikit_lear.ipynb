# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Scikit_learning/blob/main/Train_test_split_with_python_machine_learning_scikit_lear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('500hits.csv',encoding='latin-1')

# %%
df.head()
# Out:
#          PLAYER  YRS     G     AB     R     H   2B  ...   RBI    BB    SO   SB   CS     BA  HOF
# 0       Ty Cobb   24  3035  11434  2246  4189  724  ...   726  1249   357  892  178  0.366    1
# 1   Stan Musial   22  3026  10972  1949  3630  725  ...  1951  1599   696   78   31  0.331    1
# 2  Tris Speaker   22  2789  10195  1882  3514  792  ...   724  1381   220  432  129  0.345    1
# 3   Derek Jeter   20  2747  11195  1923  3465  544  ...  1311  1082  1840  358   97  0.310    1
# 4  Honus Wagner   21  2792  10430  1736  3430  640  ...     0   963   327  722   15  0.329    1
#
# [5 rows x 16 columns]

# %%
X=df.drop(columns=['PLAYER','HOF'])

# %%
y=df["HOF"]

# %%
X.head()
# Out:
#    YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB   CS     BA
# 0   24  3035  11434  2246  4189  724  295  117   726  1249   357  892  178  0.366
# 1   22  3026  10972  1949  3630  725  177  475  1951  1599   696   78   31  0.331
# 2   22  2789  10195  1882  3514  792  222  117   724  1381   220  432  129  0.345
# 3   20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358   97  0.310
# 4   21  2792  10430  1736  3430  640  252  101     0   963   327  722   15  0.329

# %%
X.shape
# Out:
# (465, 14)

# %%
y.shape
# Out:
# (465,)

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: HOF, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=11,test_size=0.2)

# %%
X_train.shape
# Out:
# (372, 14)

# %%
X_test.shape
# Out:
# (93, 14)

# %%
y_train.shape
# Out:
# (372,)

# %%
y_test.shape
# Out:
# (93,)

# %%
X_train.head()
# Out:
#      YRS     G    AB     R     H   2B   3B   HR   RBI    BB    SO   SB   CS     BA
# 289   18  2028  7298   873  1993  284   40  325  1163   620  1313   20   38  0.273
# 288   13  1836  6826   856  1996  392  117   43   402   513   360  247  108  0.292
# 350   14  1799  6373   876  1854  282   64   49   630   844   627   37   51  0.291
# 196   17  2158  7911  1057  2276  414   92   94   844   690   784  246  138  0.288
# 184   19  2390  8570  1386  2369  420   65  244  1084  1197  1099  143   75  0.276

# %%
X_train.describe().round(3)
# Out:
#            YRS         G         AB         R  ...        SO        SB       CS       BA
# count  372.000   372.000    372.000   372.000  ...   372.000   372.000  372.000  372.000
# mean    17.011  2046.522   7526.078  1154.126  ...   850.323   196.927   58.987    0.289
# std      2.662   351.233   1302.406   291.308  ...   472.918   185.586   49.322    0.021
# min     11.000  1331.000   4981.000   651.000  ...     0.000     7.000    0.000    0.246
# 25%     15.000  1797.500   6507.500   936.000  ...   448.000    64.500   23.000    0.274
# 50%     17.000  1992.000   7237.000  1099.000  ...   844.000   141.000   52.000    0.288
# 75%     19.000  2245.500   8198.250  1305.000  ...  1234.250   285.500   84.000    0.300
# max     26.000  3308.000  12364.000  2295.000  ...  1936.000  1406.000  335.000    0.366
#
# [8 rows x 14 columns]

# %%
X_test.describe().round(3)
# Out:
#           YRS         G         AB         R  ...        SO       SB       CS      BA
# count  93.000    93.000     93.000    93.000  ...    93.000   93.000   93.000  93.000
# mean   17.204  2057.409   7452.968  1135.065  ...   836.065  191.817   54.473   0.287
# std     3.154   368.580   1265.371   283.877  ...   552.309  166.926   42.508   0.022
# min    11.000  1399.000   5472.000   601.000  ...    15.000    8.000    0.000   0.248
# 25%    15.000  1820.000   6622.000   935.000  ...   359.000   61.000   15.000   0.272
# 50%    17.000  1997.000   7359.000  1108.000  ...   745.000  137.000   50.000   0.285
# 75%    19.000  2282.000   8096.000  1283.000  ...  1179.000  271.000   83.000   0.299
# max    25.000  2850.000  10876.000  1859.000  ...  2597.000  744.000  173.000   0.340
#
# [8 rows x 14 columns]
