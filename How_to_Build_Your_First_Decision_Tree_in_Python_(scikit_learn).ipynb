# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Scikit_learning/blob/main/How_to_Build_Your_First_Decision_Tree_in_Python_(scikit_learn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/Davron030901/Scikit_learning/main/data/500hits.csv
# Out:
# --2024-12-25 03:59:46--  https://raw.githubusercontent.com/Davron030901/Scikit_learning/main/data/500hits.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34825 (34K) [application/octet-stream]
# Saving to: ‘500hits.csv.1’
#
# 500hits.csv.1       100%[===================>]  34.01K  --.-KB/s    in 0.007s
#
# 2024-12-25 03:59:46 (4.61 MB/s) - ‘500hits.csv.1’ saved [34825/34825]

# %%
df=pd.read_csv('/content/500hits.csv',encoding='latin-1')

# %%
df.head()
# Out:
#          PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0       Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1   Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2  Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3   Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4  Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
#
#      SO   SB   CS     BA  HOF
# 0   357  892  178  0.366    1
# 1   696   78   31  0.331    1
# 2   220  432  129  0.345    1
# 3  1840  358   97  0.310    1
# 4   327  722   15  0.329    1

# %%
df=df.drop(columns=['PLAYER','CS'])

# %%
df.head()
# Out:
#    YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB     BA  \
# 0   24  3035  11434  2246  4189  724  295  117   726  1249   357  892  0.366
# 1   22  3026  10972  1949  3630  725  177  475  1951  1599   696   78  0.331
# 2   22  2789  10195  1882  3514  792  222  117   724  1381   220  432  0.345
# 3   20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358  0.310
# 4   21  2792  10430  1736  3430  640  252  101     0   963   327  722  0.329
#
#    HOF
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
X=df.iloc[:,:13]

# %%
y=df.iloc[:,13]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=17,test_size=0.2)

# %%
X_train.shape
# Out:
# (372, 13)

# %%
X_test.shape
# Out:
# (93, 13)

# %%
y_train.shape
# Out:
# (372,)

# %%
y_test.shape
# Out:
# (93,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[52  9]
#  [10 22]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85        61
#            1       0.71      0.69      0.70        32
#
#     accuracy                           0.80        93
#    macro avg       0.77      0.77      0.77        93
# weighted avg       0.79      0.80      0.79        93

# %%
dtc.feature_importances_
# Out:
# array([0.0147551 , 0.0154869 , 0.06208512, 0.05593063, 0.38738161,
#        0.04325963, 0.06749158, 0.        , 0.10478776, 0.05944383,
#        0.04220605, 0.05078727, 0.09638455])

# %%
X.columns
# Out:
# Index(['YRS', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'SB',
#        'BA'],
#       dtype='object')

# %%
features=pd.DataFrame(dtc.feature_importances_,index=X.columns)

# %%
features.head(15)
# Out:
#             0
# YRS  0.014755
# G    0.015487
# AB   0.062085
# R    0.055931
# H    0.387382
# 2B   0.043260
# 3B   0.067492
# HR   0.000000
# RBI  0.104788
# BB   0.059444
# SO   0.042206
# SB   0.050787
# BA   0.096385

# %%
dtc2=DecisionTreeClassifier(criterion='entropy',ccp_alpha=0.04)

# %%
dtc2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.04, criterion='entropy')

# %%
y_pred2=dtc2.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred2))
# Out:
# [[50 11]
#  [ 9 23]]

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83        61
#            1       0.68      0.72      0.70        32
#
#     accuracy                           0.78        93
#    macro avg       0.76      0.77      0.77        93
# weighted avg       0.79      0.78      0.79        93

# %%
features2=pd.DataFrame(dtc2.feature_importances_,index=X.columns)

# %%
features2.head(15)
# Out:
#             0
# YRS  0.000000
# G    0.000000
# AB   0.000000
# R    0.000000
# H    0.837977
# 2B   0.000000
# 3B   0.000000
# HR   0.000000
# RBI  0.000000
# BB   0.000000
# SO   0.000000
# SB   0.000000
# BA   0.162023
