# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Scikit_learning/blob/main/Mastering_Multiple_Linear_Regression_in_Scikit_Learn_A_Step_by_Step_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import numpy as np

# %%
data=[]

for _ in range(500):
  team_name=f"Team {chr(random.randint(65,90))}"
  season=random.randint(2010,2024)
  wins=random.randint(50,110)
  losses=162-wins
  hits=random.randint(1200,1600)
  doubles=random.randint(200,350)
  triples=random.randint(10,40)
  home_runs=random.randint(100,250)
  strikeouts=random.randint(1000,1500)

  hits_adjusted=hits+(wins-80)*5
  doubles_adjusted=doubles+(wins-80)*2
  triples_adjusted=triples+(wins-80)
  home_runs_adjusted=home_runs+(wins-80)*3
  srtikeouts_adjusted=strikeouts-(wins-80)*10

  data.append([team_name,season,wins,losses,hits_adjusted,doubles_adjusted,triples_adjusted,home_runs_adjusted,srtikeouts_adjusted])

# %%
columns=["Team","Season","Wins","Losses","Hits","Doubles","Triples","HomeRuns","Strikeouts"]
df=pd.DataFrame(data,columns=columns)

# %%
df.head()
# Out:
#      Team  Season  Wins  Losses  Hits  Doubles  Triples  HomeRuns  Strikeouts
# 0  Team G    2022    52     110  1262      277      -17        66        1371
# 1  Team Q    2012    88      74  1463      283       33       237        1224
# 2  Team X    2020    91      71  1354      359       50       264        1103
# 3  Team D    2021    82      80  1503      224       26       140        1180
# 4  Team B    2011    99      63  1501      273       55       201        1137

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lmplot(x='Hits',y='Wins',data=df)
plt.show()

# %%
sns.lmplot(x='Strikeouts',y='Wins',data=df)
plt.show()

# %%
df2=df.drop(columns=['Team','Season','Losses'],axis=1)

# %%
df2.head()
# Out:
#    Wins  Hits  Doubles  Triples  HomeRuns  Strikeouts
# 0    52  1262      277      -17        66        1371
# 1    88  1463      283       33       237        1224
# 2    91  1354      359       50       264        1103
# 3    82  1503      224       26       140        1180
# 4    99  1501      273       55       201        1137

# %%
df2.columns
# Out:
# Index(['Wins', 'Hits', 'Doubles', 'Triples', 'HomeRuns', 'Strikeouts'], dtype='object')

# %%
X=df[['Hits', 'Doubles', 'Triples', 'HomeRuns', 'Strikeouts']]
y=df[['Wins']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=24)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 0.8923273484946564

# %%
lr.score(X_train,y_train)
# Out:
# 0.8941840694616011

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
y_pred=lr.predict(X_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 5.059547067345407

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 37.108302614801616

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8923273484946564

# %%
lr.coef_
# Out:
# array([[ 0.01393217,  0.04151551,  0.42708277,  0.05297523, -0.01319589]])

# %%
lr.intercept_
# Out:
# array([46.21341539])
