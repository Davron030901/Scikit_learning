# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Scikit_learning/blob/main/Random_Forest_Regressor_in_Python_A_Step_by_Step_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
healthexp=sns.load_dataset('healthexp')

# %%
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
healthexp.tail()
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0

# %%
healthexp=pd.get_dummies(healthexp,dtype=float)

# %%
X=healthexp.drop('Life_Expectancy',axis=1)
y=healthexp['Life_Expectancy']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=19)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor(random_state=13)

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=13)

# %%
y_pred=rfr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.25916363636361917

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.10221141818181628

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9910457602615238

# %%
param_grid={
    'n_estimators':[100,200,300],
    'max_depth':[10,20,30],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
rfr_cv=GridSearchCV(estimator=rfr,param_grid=param_grid,cv=3,n_jobs=-1,scoring="neg_mean_squared_error")

# %%
rfr_cv.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=13), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='neg_mean_squared_error')

# %%
y_pred2=rfr_cv.predict(X_test)

# %%
mean_absolute_error(y_test,y_pred2)
# Out:
# 0.25089696969702713

# %%
mean_squared_error(y_test,y_pred2)
# Out:
# 0.09636595151516295

# %%
r2_score(y_test,y_pred2)
# Out:
# 0.9915578528520343
