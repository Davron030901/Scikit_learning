# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Scikit_learning/blob/main/Hands_On_Machine_Learning_Logistic_Regression_with_Python_and_Scikit_Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Logistic Regression
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

# %%
# answers1 = np.random.choice(['no'], 30)
# answers2=np.random.choice(['yes'],70)
# answers=np.concatenate((answers1,answers2))
# answers
# number1=np.random.randint(15,100,50)
# number2=np.random.randint(30,125,50)
# numbers=np.concatenate((number1,number2))
# numbers
# Out:
# array(['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes'], dtype='<U3')

# %%
d={'miles_per_week':[15,17,  38,  43,  38,  59,  21,  54,  87,  42,  89,66,  38,  26,  33,  99,  60,  59,  88,  18,  68,  84,  88,
        99,  40,  57, 109,
        80,  87,  57,  89,  30,  32,  73,  90, 110, 121, 108, 123,  56,
        66,  49,  84,  62,  30, 103,  79,  71, 122,  47, 110,  83,  36,
        55,  53,  57,  39,  98,  60,  55, 114,  53,  35, 100,  63,  61,
        72,  93,  85,  70,  88,  30,  38,  30,93,95,96,97,98,99,110,111,113,114,115,116,116,118,119,120,121,123,124,126,62,67,74,79,90,112],
   'completed_50m_ultra':['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
       'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
       'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
       'yes', 'yes', 'yes', 'yes', 'yes']}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#     miles_per_week completed_50m_ultra
# 0               15                  no
# 1               17                  no
# 2               38                  no
# 3               43                  no
# 4               38                  no
# ..             ...                 ...
# 95              67                 yes
# 96              74                 yes
# 97              79                 yes
# 98              90                 yes
# 99             112                 yes
#
# [100 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
finished_race=['no','yes']

# %%
enc=OrdinalEncoder(categories=[finished_race])

# %%
df['completed_50m_ultra']=enc.fit_transform(df[['completed_50m_ultra']])

# %%
df
# Out:
#     miles_per_week  completed_50m_ultra
# 0               15                  0.0
# 1               17                  0.0
# 2               38                  0.0
# 3               43                  0.0
# 4               38                  0.0
# ..             ...                  ...
# 95              67                  1.0
# 96              74                  1.0
# 97              79                  1.0
# 98              90                  1.0
# 99             112                  1.0
#
# [100 rows x 2 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df.miles_per_week,df.completed_50m_ultra)

# %%
import seaborn as sns

# %%
sns.countplot(x='completed_50m_ultra',data=df)
# Out:
# <Axes: xlabel='completed_50m_ultra', ylabel='count'>

# %%
X=df.iloc[:,:1]
y=df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=11)

# %%
X_train.shape
# Out:
# (80, 1)

# %%
X_test.shape
# Out:
# (20, 1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 1  3]
#  [ 1 15]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.25      0.33         4
#          1.0       0.83      0.94      0.88        16
#
#     accuracy                           0.80        20
#    macro avg       0.67      0.59      0.61        20
# weighted avg       0.77      0.80      0.77        20
