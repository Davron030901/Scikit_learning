# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Scikit_learning/blob/main/scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
from sklearn.datasets import load_iris

# %%
meta_data = load_iris()

# %%
df =pd.DataFrame(meta_data.data, columns=meta_data.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df_sns=sns.load_dataset('iris')
df_sns
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normalizing=MinMaxScaler()

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
data=normalizing.fit_transform(df)

# %%
data
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
df_norm=pd.DataFrame(data, columns=df.columns)
df_norm
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0             0.222222          0.625000           0.067797          0.041667
# 1             0.166667          0.416667           0.067797          0.041667
# 2             0.111111          0.500000           0.050847          0.041667
# 3             0.083333          0.458333           0.084746          0.041667
# 4             0.194444          0.666667           0.067797          0.041667
# ..                 ...               ...                ...               ...
# 145           0.666667          0.416667           0.711864          0.916667
# 146           0.555556          0.208333           0.677966          0.750000
# 147           0.611111          0.416667           0.711864          0.791667
# 148           0.527778          0.583333           0.745763          0.916667
# 149           0.444444          0.416667           0.694915          0.708333
#
# [150 rows x 4 columns]

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df_norm.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            0.428704          0.440556           0.467458
# std             0.230018          0.181611           0.299203
# min             0.000000          0.000000           0.000000
# 25%             0.222222          0.333333           0.101695
# 50%             0.416667          0.416667           0.567797
# 75%             0.583333          0.541667           0.694915
# max             1.000000          1.000000           1.000000
#
#        petal width (cm)
# count        150.000000
# mean           0.458056
# std            0.317599
# min            0.000000
# 25%            0.083333
# 50%            0.500000
# 75%            0.708333
# max            1.000000

# %%
sns.pairplot(df)

# %%
sns.pairplot(df_norm)

# %%
from sklearn.preprocessing import StandardScaler
standard=StandardScaler()

# %%
data_std=standard.fit(df)
data_std=standard.fit_transform(df_std)
data_std
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
df_std=pd.DataFrame(data_std, columns=df.columns)
df_std
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0            -0.900681          1.019004          -1.340227         -1.315444
# 1            -1.143017         -0.131979          -1.340227         -1.315444
# 2            -1.385353          0.328414          -1.397064         -1.315444
# 3            -1.506521          0.098217          -1.283389         -1.315444
# 4            -1.021849          1.249201          -1.340227         -1.315444
# ..                 ...               ...                ...               ...
# 145           1.038005         -0.131979           0.819596          1.448832
# 146           0.553333         -1.282963           0.705921          0.922303
# 147           0.795669         -0.131979           0.819596          1.053935
# 148           0.432165          0.788808           0.933271          1.448832
# 149           0.068662         -0.131979           0.762758          0.790671
#
# [150 rows x 4 columns]

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df_std.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count       1.500000e+02      1.500000e+02       1.500000e+02
# mean        9.473903e-17     -4.736952e-17       1.421085e-16
# std         1.003350e+00      1.003350e+00       1.003350e+00
# min        -1.870024e+00     -2.433947e+00      -1.567576e+00
# 25%        -9.006812e-01     -5.923730e-01      -1.226552e+00
# 50%        -5.250608e-02     -1.319795e-01       3.364776e-01
# 75%         6.745011e-01      5.586108e-01       7.627583e-01
# max         2.492019e+00      3.090775e+00       1.785832e+00
#
#        petal width (cm)
# count      1.500000e+02
# mean       4.736952e-16
# std        1.003350e+00
# min       -1.447076e+00
# 25%       -1.183812e+00
# 50%        1.325097e-01
# 75%        7.906707e-01
# max        1.712096e+00

# %%
sns.pairplot(df_std)

# %%
df_std['sepal width (cm)'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_std['sepal width (cm)'].std()
# Out:
# 1.0033500931359767

# %%
df_std['sepal width (cm)'].min()
# Out:
# -2.43394714190809

# %%
arr_norm=np.random.normal(1.3,3.5,size=1000)

# %%
arr_norm
# Out:
# array([ 3.46165719e+00,  5.99958595e+00, -1.99693980e+00, -4.08436631e+00,
#         4.61811141e+00,  1.09563339e+00, -1.18714633e+00, -4.54408438e+00,
#         4.81266029e-01, -1.14705713e+00,  1.97356470e+00,  1.62096014e-01,
#        -2.21091237e+00,  4.45509831e+00,  5.07017429e+00,  2.53426035e+00,
#        -1.66874544e+00,  2.90446757e+00,  4.50694290e+00, -2.17450244e+00,
#         4.90789363e+00,  6.33233520e+00,  2.78040761e+00, -3.14459587e+00,
#         4.73105590e+00, -1.02241810e+00,  1.76109918e+00, -7.66310395e+00,
#         5.86246670e-01, -5.69128085e+00,  7.06170321e+00,  5.42660989e+00,
#         2.67969150e+00, -8.13895984e-01, -4.45717160e+00, -8.90642711e-01,
#         4.29812971e-01,  1.68873004e+00,  4.20743335e+00, -2.81910420e+00,
#         1.80424784e+00,  2.68034431e+00,  1.42829818e+00,  1.70702598e+00,
#        -3.58915876e+00,  7.63770876e-01,  9.68824654e+00, -2.42267005e+00,
# ...

# %%
arr_norm=pd.DataFrame(arr_norm)
arr_norm.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
arr_norm.mean(), arr_norm.std()
# Out:
# (1.1666194316294989, 3.4242797644384706)

# %%
arr_s=standard.fit_transform(arr_norm.reshape(-1,1))

# %%
arr_s=pd.DataFrame(arr_s)
arr_s.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
